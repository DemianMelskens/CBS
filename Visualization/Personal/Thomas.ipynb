# %% [markdown]
# # Initial analysis
#
# A first look at the received data from CBS
#
#
# ### Initialization
# Initialization of the libraries and csv or excel data files

# %%
import urllib.request as urllib, os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

filename = 'Coosto_berichten.csv'
datafolder = 'data/'

try:
    os.mkdir(datafolder)
except FileExistsError:
    pass

data = pd.read_csv('data/' + filename, delimiter=';')

# %% [markdown]
# ### Cleaning
# After the initialization a cleaning and possibly enriching process will be performed to make the data usable.

# %%
def count_missing(x):
  return sum(x.isnull())
print("Missing values per column:")
print(data.apply(count_missing, axis=0))
# Out:
# Missing values per column:
# Unnamed: 0             0
# Unnamed: 0.1           0
# Unnamed: 0.1.1         0
# datum                  0
# url                    0
# sentiment              0
# discussielengte        0
# views                  0
# auteur                 0
# GPS breedtegraad    3837
# GPS lengtegraad     3837
# bericht tekst         17
# likes count            0
# datum utc              0
# hashtags               0
# dtype: int64

# %% [markdown]
# ### Pie chart
#
# <<explanation>>

# %%
# Sentiment neutral
print('Neutral: ', len(data.loc[data['sentiment']=='0']))

# Sentiment positive
print('Positive: ', len(data.loc[data['sentiment'] == '+']))

# Sentiment negative
print('Negative: ', len(data.loc[data['sentiment'] == '-']))

# Pie chart
pd.DataFrame({'Sentiment': [len(data.loc[data['sentiment'] == '0']), 
                          len(data.loc[data['sentiment'] == '+']),
                          len(data.loc[data['sentiment'] == '-'])]}, index=['Neutral', 'Positive', 'Negative']).plot.pie(y='Sentiment', figsize=(8,8))
# Out:
# Neutral:  5242
# Positive:  3045
# Negative:  150

# %% [markdown]
# ### Comments vs post

# %%
# Pie chart
#pd.DataFrame({'Type': [len(data.loc[data['type'] == 'post']),
                          #len(data.loc[data['type'] == 'comment'])]}, index=['Post', 'Comment']).plot.pie(y='Type', figsize=(8,8))

# %% [markdown]
# ### Bar chart
#
# <<explanation>>

# %%
data.sort_values(by='views', ascending=False).head(10)

data.sort_values(by='views', ascending=False).head(20)\
    .plot.bar(x='auteur', y=['views', 'discussielengte'], rot=90, subplots=True, figsize=(12,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000234CE62BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000234CE661FD0>],
#       dtype=object)

# %% [markdown]
# ### Scatter chart
#
# <>

# %%
data_gps = data
data_gps = data_gps.loc[3.2 <= data_gps['GPS lengtegraad']]
data_gps = data_gps.loc[7.4 >= data_gps['GPS lengtegraad']]
data_gps = data_gps.loc[50.7 <= data_gps['GPS breedtegraad']]
data_gps = data_gps.loc[53.6 >= data_gps['GPS breedtegraad']]

plt.figure(figsize=[10,10]);

plt.title('Insta of The Netherlands')
plt.xlabel('longitude')
plt.ylabel('latitude')
#plt.xlim(3.2,7.4)
#plt.ylim(50.7,53.6)
sizes = 120

print('Within The Netherlands:', len(data_gps), 'of', len(data))

points=plt.scatter(data_gps['GPS lengtegraad'], data_gps['GPS breedtegraad'], marker='.'
                   , c=data_gps.views
                   , s=sizes**1
                   , alpha=0.3
                   , cmap='viridis')

plt.clim(0,1000)

plt.colorbar(label='Views');
# Out:
# Within The Netherlands: 4422 of 8437

# %%
# Under construction because of the cleaning

# plt.figure(figsize=[10,10]);

# plt.title('Views vs discussion')
# plt.xlabel('views')
# plt.ylabel('discussionlength')
# #plt.xlim(3.2,7.4)
# #plt.ylim(50.7,53.6)
# sizes = 120

# points=plt.scatter(data['views'], data_gps['discussielengte'], marker='.'
#                    , s=sizes**1
#                    , alpha=0.3
#                    , cmap='binary')

# plt.clim(0,1000)

# %% [markdown]
# ## Area chart
#
# <<explanation>>

# %% [markdown]
# ## Line chart
#
# <<explanation>>

# %%
# Step 1: Convert to datetime
data['datum'] = pd.to_datetime(data['datum'], errors='coerce')
# Step 2: Make extra column with month number
data['Month'] = data['datum'].dt.month

data['Month'].value_counts().sort_index().plot(title='Number of views per month', \
                                               figsize=(20,10))
plt.xlabel('Month')
plt.ylabel('Number of posts')
# Out:
# Text(0,0.5,'Number of posts')

# %% [markdown]
# ## Scatter matrix
#
# <<explanation>>

# %% [markdown]
# ## Histogram
#
# <<explanation>>

# %% [markdown]
# We're gonna start with seeing how many times someone posts more than once. So this means that for example there could be three people who have posted 8 times. This would be represented as 8 -- 3

# %%
data.head(10)
x = data['auteur'].value_counts()
x.value_counts().sort_index()

# Plotting is not useful yet, more data needed
# plt.hist(x)
# plt.show()
# Out:
# 1    7165
# 2     400
# 3      86
# 4      21
# 5      15
# 6       4
# 7       2
# 8       1
# 9       1
# Name: auteur, dtype: int64

# %%
data['datum'] = data['datum'].astype("datetime64")

fig = plt.figure(figsize=(20,10))

bins = 500
plt.hist(data['datum'], bins=bins)

plt.xlabel('Date')
plt.ylabel('Amount of posts')
plt.title('Histogram of the amount of posts')
plt.show()

# %%
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1             datum  \
# 0            0             0               0  2018-03-29 14:45
# 1            1             1               1  2018-01-01 13:52
# 2            2             2               2  2018-02-28 13:15
# 3            3             3               3  2017-10-19 19:15
# 4            4             4               4  2017-09-02 11:17
# 5            5             5               5  2017-11-17 08:36
# 6            6             6               6  2017-01-25 07:32
# 7            7             7               7  2017-05-10 17:24
# 8            8             8               8  2018-01-05 19:27
# 9            9             9               9  2017-11-23 19:28
# 10          10            10              10  2017-04-24 15:25
# 11          11            11              11  2017-11-03 17:11
# 12          12            12              12  2017-02-24 06:59
# 13          13            13              15  2017-08-08 11:05
# 14          14            14              16  2017-07-04 20:30
# 15          15            15              17  2017-10-25 14:09
# 16          16            16              18  2017-07-29 18:58
# 17          17            17              19  2018-03-12 15:07
# 18          18            18              20  2017-08-13 20:39
# 19          19            19              22  2018-01-29 17:34
#
#                                      url sentiment  discussielengte  views  \
# 0   https://instagram.com/p/Bg6FiptlWhz/         0              0.0   33.0
# 1   https://instagram.com/p/BdaFBieFJ8X/         0              0.0   31.0
# 2   https://instagram.com/p/BfvXGkyhiSf/         0              1.0   11.0
# 3   https://instagram.com/p/BacAeTuAyyi/         0              0.0   12.0
# 4   https://instagram.com/p/BYiIer7laoM/         0              0.0   34.0
# 5   https://instagram.com/p/BblpQI3FAYh/         0              0.0   35.0
# 6   https://instagram.com/p/BPrWrQVAtLP/         0              0.0  113.0
# 7   https://instagram.com/p/BT6rCQRAgb5/         0              2.0   43.0
# 8   https://instagram.com/p/Bdk-v8KleGR/         0             81.0  788.0
# 9   https://instagram.com/p/Bb2QrKmFZFI/         +              1.0   28.0
# 10  https://instagram.com/p/BTRQqe6B5lG/         0              0.0   27.0
# 11  https://instagram.com/p/BbChG8GF8X5/         0              1.0   54.0
# 12  https://instagram.com/p/BQ4ixfllD5L/         0              2.0   39.0
# 13  https://instagram.com/p/BXhvI23giRX/         +              0.0   19.0
# 14  https://instagram.com/p/BWIoB3dAeQj/         0              2.0   17.0
# 15  https://instagram.com/p/Baq6SXSAlng/         0              0.0   12.0
# 16  https://instagram.com/p/BXI1XRrDWd_/         0              0.0   12.0
# 17  https://instagram.com/p/BgOddwhALVv/         +              4.0   99.0
# 18  https://instagram.com/p/BXvo4WYDWi4/         0              1.0   22.0
# 19  https://instagram.com/p/Beik32FBDo0/         0              0.0   54.0
#
#                     auteur  GPS breedtegraad  GPS lengtegraad  \
# 0          sizezeroalkmaar         52.629131         4.749720
# 1           estherfeenstra         53.303810         5.052010
# 2   someguyslivinginahouse         51.916698         4.500000
# 3             skinpractica               NaN              NaN
# 4     susannetendoesschate         51.986523         5.834437
# 5      atelieranitadegroot         51.916698         4.400000
# 6               eftelmagic               NaN              NaN
# 7        adventureofastone               NaN              NaN
# 8               nikiellena         51.918327         4.479324
# 9        foreveryoungdelft         52.011902         4.357050
# 10  joodscultureelkwartier         52.366879         4.910950
# 11      moviperformancegym         52.039261         5.559490
# 12             eaglesranch         53.066711         4.788520
# 13                marteijn         51.566666         3.750000
# 14             tomtomtomgo         51.700001         5.316670
# 15             janssen9798               NaN              NaN
# 16               slomocrew               NaN              NaN
# 17   caroline_van_zeumeren               NaN              NaN
# 18      lamiacucinawijchen         51.810101         5.738180
# 19   jeroenboschziekenhuis         51.685513         5.277732
#
#                                         bericht tekst  likes count  \
# 0   Je hebt het druk, maar wilt toch graag aan je ...         33.0
# 1                           Gelukkig nieuwjaar!               31.0
# 2   Wandering around Rotterdam with the housemates...         11.0
# 3   Skinpractica voor al uw huid en laserbehandeli...         12.0
# 4   Deze toppers van @2gettherecoaching lopen vand...         34.0
# 5   The most wonderful time of the year  can’t wai...         35.0
# 6   // Fakir // . . . //                 @efteling //        113.0
# 7                  Spring bouquet                             43.0
# 8   One of my favorite hotspots in Rotterdam, I am...        788.0
# 9   Black Friday bij Forever Young: dat betekent 2...         28.0
# 10  Net als andere gevluchte fotografen zoals Eric...         27.0
# 11  Nothing worth having comes easy • Er wordt har...         54.0
# 12                                www.eaglesranch.com         39.0
# 13  Hoppa, weer 12km in de benen  heerlijke run do...         19.0
# 14                                                            17.0
# 15           Het laatste stukje blauwe  vandaag.              12.0
# 16  We zijn in 010 voor een volgende EK wedstrijd ...         12.0
# 17  Paddenstoelen op een omgezaagde boom.#        ...         99.0
# 18                               @lamiacucinawijchen          22.0
# 19  Hoog bezoek vandaag. Paul Blokhuis, staatssecr...         54.0
#
#               datum utc                                           hashtags
# 0   2018-03-29 12:45:14  ['salon', 'alkmaar', 'sizezero', 'shape', 'fit...
# 1   2018-01-01 12:52:05  ['bikkels', 'zijlieverdanik', 'unox', 'happyne...
# 2   2018-02-28 12:15:39  ['coliving', 'sharedliving', 'sharedhouse', 's...
# 3   2017-10-19 17:15:22  ['Skinpractica', 'Rotterdam', 'LaanopZuid145',...
# 4   2017-09-02 09:17:59  ['airborne', 'airbornewandeltocht', 'lopen', '...
# 5   2017-11-17 07:36:15                ['atelieranitadegroot', 'schiedam']
# 6   2017-01-25 06:32:39  ['Efteling', 'Fakir', 'Sprookjesbos', 'Fairyta...
# 7   2017-05-10 15:24:44  ['spring', 'lente', 'bouquet', 'boeket', 'flow...
# 8   2018-01-05 18:27:39  ['hotspot', 'hotspotrotterdam', 'sappi', 'sapp...
# 9   2017-11-23 18:28:35     ['delft', 'shoppen', 'fashion', 'blackfriday']
# 10  2017-04-24 13:25:26  ['Erich', 'Salomon', 'Annemie', 'Helmuth', 'Wo...
# 11  2017-11-03 16:11:40  ['movi', 'movigym', 'moviperformancegym', 'vee...
# 12  2017-02-24 05:59:52  ['bonteTexelseSchapen', 'BonteSchapen', 'BontS...
# 13  2017-08-08 09:05:09  ['NeverNotRunning', 'KeepOnRunning', 'lovezeel...
# 14  2017-07-04 18:30:37  ['fotoday', 'sintjan', 'bezoekdenbosch', 'sher...
# 15  2017-10-25 12:09:55  ['lucht', 'nederland', 'brabant', 'someren', '...
# 16  2017-07-29 16:58:32         ['knvb', 'director', 'evsoperator', 'evs']
# 17  2018-03-12 14:07:42  ['nederlandismooi', 'nederland', 'leusden', 'p...
# 18  2017-08-13 18:39:50   ['catering', 'bestellen', 'wijchen', 'goodfood']
# 19  2018-01-29 16:34:58  ['vws', 'politiek', 'overgewicht', 'kinderen',...
