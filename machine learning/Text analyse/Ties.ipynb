# %%
import numpy as np
import sklearn as sk
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import sys
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
# retrieve data
insta = pd.read_csv('././data/merged_file.csv', delimiter=';')
insta.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Unnamed: 0.1</th>
#       <th>datum</th>
#       <th>url</th>
#       <th>sentiment</th>
#       <th>discussielengte</th>
#       <th>views</th>
#       <th>auteur</th>
#       <th>GPS breedtegraad</th>
#       <th>GPS lengtegraad</th>
#       <th>bericht tekst</th>
#       <th>likes count</th>
#       <th>datum utc</th>
#       <th>hashtags</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>2017-06-20 17:06</td>
#       <td>https://instagram.com/p/BVjjp3Cl4uK/</td>
#       <td>0</td>
#       <td>8.0</td>
#       <td>31.0</td>
#       <td>marusinalavka</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>@_korobo_  кстати хочу сказать, что коробочки ...</td>
#       <td>31.0</td>
#       <td>2017-06-20 09:00:29</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>2017-10-10 21:43</td>
#       <td>https://instagram.com/p/BaFFd0fBbcw/</td>
#       <td>0</td>
#       <td>62.0</td>
#       <td>3639.0</td>
#       <td>artofobservance</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>So chic</td>
#       <td>3639.0</td>
#       <td>2017-10-10 19:36:27</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>2</td>
#       <td>2017-04-28 16:47</td>
#       <td>https://instagram.com/p/BTbF7AEDgHg/</td>
#       <td>0</td>
#       <td>1368.0</td>
#       <td>533961.0</td>
#       <td>amigabali</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Incredible</td>
#       <td>533961.0</td>
#       <td>2017-04-28 09:03:58</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4</td>
#       <td>2017-09-04 22:22</td>
#       <td>https://instagram.com/p/BYoVU-GFypi/</td>
#       <td>0</td>
#       <td>43.0</td>
#       <td>2224.0</td>
#       <td>gpazminoyepez</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>@divaribas.82 aloe y fibern plus. Escribame 09...</td>
#       <td>2224.0</td>
#       <td>2017-09-04 19:05:41</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6</td>
#       <td>6</td>
#       <td>2017-11-08 10:29</td>
#       <td>https://instagram.com/p/BbOnSBlFwmo/</td>
#       <td>+</td>
#       <td>12.0</td>
#       <td>46.0</td>
#       <td>laurienblomphotography</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>@remkevet oooh wat goed haha, heerlijk!:)</td>
#       <td>46.0</td>
#       <td>2017-11-08 08:56:30</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
new_set = insta[['auteur', 'bericht tekst', 'hashtags']]

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(new_set)
X_train_counts.shape
# Out:
# (3, 4)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (3, 4)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, new_set.target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-128decf7af4e> in <module>()
#       1 from sklearn.naive_bayes import MultinomialNB
# ----> 2 clf = MultinomialNB().fit(X_train_tfidf, new_set.target)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'target'
