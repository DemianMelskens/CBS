# %%
import numpy as np
import sklearn as sk
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import sys
import re
import numpy as np

# %%
# retrieve data
insta = pd.read_csv('../../data/merged_file.csv', delimiter=';')
insta.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1             datum  \
# 0            0             0  2017-06-20 17:06
# 1            1             1  2017-10-10 21:43
# 2            2             2  2017-04-28 16:47
# 3            4             4  2017-09-04 22:22
# 4            6             6  2017-11-08 10:29
# 5            8             8  2017-07-20 08:02
# 6            9             9  2018-02-10 22:27
# 7           10            10  2018-02-21 18:01
# 8           11            11  2017-08-28 17:40
# 9           12            12  2017-03-30 22:45
# 10          13            13  2017-06-07 21:16
# 11          14            14  2018-02-17 00:23
# 12          15            15  2018-01-05 23:19
# 13          16            16  2017-02-10 13:05
# 14          18            18  2017-07-12 19:48
# 15          19            19  2017-12-28 01:20
# 16          20            20  2017-01-07 23:11
# 17          21            21  2017-08-23 12:42
#
#                                      url sentiment  discussielengte     views  \
# 0   https://instagram.com/p/BVjjp3Cl4uK/         0              8.0      31.0
# 1   https://instagram.com/p/BaFFd0fBbcw/         0             62.0    3638.0
# 2   https://instagram.com/p/BTbF7AEDgHg/         0           1367.0  533909.0
# 3   https://instagram.com/p/BYoVU-GFypi/         0             43.0    2224.0
# 4   https://instagram.com/p/BbOnSBlFwmo/         +             12.0      46.0
# 5   https://instagram.com/p/BWwfFxkFoHW/         0              0.0      64.0
# 6   https://instagram.com/p/Bdp4B0Pj6TL/         0           9410.0  223430.0
# 7   https://instagram.com/p/BfdzxFYlj-h/         +            697.0  103810.0
# 8   https://instagram.com/p/BYVy0NRBGdr/         0              2.0      17.0
# 9   https://instagram.com/p/BSRrHmbDSui/         0              9.0      91.0
# 10  https://instagram.com/p/BVDLFfaFllE/         0              9.0      84.0
# 11  https://instagram.com/p/BfRhTsqjm6w/         -            188.0    3909.0
# 12  https://instagram.com/p/BdlZSuUAd6B/         0              2.0      48.0
# 13  https://instagram.com/p/BQVHc0QAqTd/         -              6.0     178.0
# 14  https://instagram.com/p/BWdITU8hZ9Q/         0             94.0    7166.0
# 15  https://instagram.com/p/BdMzeXkjvHW/         0           1458.0  291296.0
# 16  https://instagram.com/p/BM4jI_3g7a2/         0           5153.0  965351.0
# 17  https://instagram.com/p/BYIOeycFiWq/         0              3.0      87.0
#
#                      auteur  GPS breedtegraad  GPS lengtegraad  \
# 0             marusinalavka               NaN              NaN
# 1           artofobservance               NaN              NaN
# 2                 amigabali               NaN              NaN
# 3             gpazminoyepez               NaN              NaN
# 4    laurienblomphotography               NaN              NaN
# 5            breaking_glass               NaN              NaN
# 6              belmacurkicc               NaN              NaN
# 7             _lilysmith97_               NaN              NaN
# 8                   heimint               NaN              NaN
# 9           bsunphotography         34.041531      -118.269028
# 10            minimemalzwei               NaN              NaN
# 11               andynuberg               NaN              NaN
# 12  chocolatealldayeveryday               NaN              NaN
# 13          arberzenelifans               NaN              NaN
# 14             martammoreda               NaN              NaN
# 15               joshrudolf               NaN              NaN
# 16                 bertem17               NaN              NaN
# 17           ucademycollege               NaN              NaN
#
#                                         bericht tekst  likes count  \
# 0   @_korobo_  кстати хочу сказать, что коробочки ...         31.0
# 1                                             So chic       3638.0
# 2                                          Incredible     533909.0
# 3   @divaribas.82 aloe y fibern plus. Escribame 09...       2224.0
# 4           @remkevet oooh wat goed haha, heerlijk!:)         46.0
# 5   Lovely Japanese copy of Pin Ups. One of my fav...         64.0
# 6                                    @amanda.carlberg     223430.0
# 7                            @nobbsy91  look at this!     103810.0
# 8                                            .......#         17.0
# 9   I can't wait to spend this weekend at  - -  to...         91.0
# 10                            Schönen Abend für Euch          84.0
# 11  Het programma word steeds slechter!!! Het nieu...       3909.0
# 12         Fancy salad                                        48.0
# 13  @teamdavidneres dus dan is hij niet meteen Een...        178.0
# 14  En manga larga y estan a 40 grados en madrid @...       7166.0
# 15                                       @jakenorth03     291296.0
# 16       I love you I reel completely grateful to you     965351.0
# 17                                               Wow!         87.0
#
#               datum utc                                           hashtags
# 0   2017-06-20 09:00:29                                                 []
# 1   2017-10-10 19:36:27                                                 []
# 2   2017-04-28 09:03:58                                                 []
# 3   2017-09-04 19:05:41                                                 []
# 4   2017-11-08 08:56:30                                                 []
# 5   2017-07-20 06:02:08  ['vinyljunkie', 'vinyladdict', 'welltempered',...
# 6   2018-01-07 16:05:07                                                 []
# 7   2018-02-21 16:39:47                                                 []
# 8   2017-08-28 14:17:47                                                 []
# 9   2017-03-30 20:45:12                               ['wondercon', 'tbt']
# 10  2017-06-07 19:10:07                                                 []
# 11  2018-02-16 22:07:36                                ['tvoh', 'notdone']
# 12  2018-01-05 22:19:35  ['ski', 'selfie', 'luxe', 'glam', 'bridal', 'b...
# 13  2017-02-10 11:47:42                                                 []
# 14  2017-07-12 17:37:26                                                 []
# 15  2017-12-27 09:07:51                                                 []
# 16  2016-11-16 19:57:30                                                 []
# 17  2017-08-23 07:50:10                                                 []

# %%
small_set = insta['auteur', 'bericht tekst', 'hashtags']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('auteur', 'bericht tekst', 'hashtags')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-6ecb434c89d2> in <module>()
# ----> 1 small_set = insta['auteur', 'bericht tekst', 'hashtags']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('auteur', 'bericht tekst', 'hashtags')
